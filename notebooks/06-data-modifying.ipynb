# %% [markdown]
# # 🐼 Pandas Handbook
#
# ## 06 - Data Modifying
#
# Check out the official [Pandas documentation](https://pandas.pydata.org/pandas-docs/stable/)
#
# This notebook uses the [Titanic - Machine Learning from Disaster dataset](https://www.kaggle.com/competitions/titanic/data) from Kaggle to demonstrate how to modify the data with pandas.

# %% [markdown]
# ## 📚 Table of Contents
#
# ---
#
# ➕ **Inserting or Dropping Columns**
# 🔪 **Splitting & Extracting Values**
# 🔗 **Merging Columns**
# ✏️ **Renaming and Formatting**
# 🧵 **Modifying Column Strings**
# 🧠 **Applying Custom Functions**
# 🎯 **Conditional Modifications**
# ✍️ **Modifying by Index or Label**
# 👉 **Next Topic: Data Combining**
#
# ---

# %%
import pandas as pd
import numpy as np
import os

# %%
data_processed = "../data/processed/"
csv_file = "clean_titanic.csv"
import_path = os.path.join(data_processed, csv_file)
df = pd.read_csv(import_path, index_col="PassengerId")

# %%
mrs_df = df.copy()
mrs_filter = mrs_df['Name'].str.contains('Mrs.')
mrs_df = mrs_df[mrs_filter]

# %% [markdown]
# ### ➕ Inserting or Dropping Columns

# %% [markdown]
# ```df.insert(POSITION, 'NEW_COLUMN', df['COLUMN1'] + df['COLUMN2'])``` – Inserts a new column at a specified position by summing two existing columns.
# ```df.insert(POSITION, 'NEW_COLUMN', df['COLUMN'] < VALUE)``` – Inserts a new column based on a condition.
# ```df.drop(columns='COLUMN', inplace=True)``` – Drops a single specified column in place.
# ```df.drop(columns=['COLUMN_1', 'COLUMN_2', ...], inplace=True)``` – Drops multiple specified columns in place.

# %%
mrs_df.insert(5, 'Family Size', mrs_df['SibSp'] + mrs_df['Parch'])
mrs_df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 9                   1       3
# 10                  1       2
# 16                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
#
#              Family Size  SibSp  Parch    Ticket     Fare    Cabin  \
# PassengerId
# 2                      1      1      0  PC 17599  71.2833      C85
# 4                      1      1      0    113803  53.1000     C123
# 9                      2      0      2    347742  11.1333  Unknown
# 10                     1      1      0    237736  30.0708  Unknown
# 16                     0      0      0    248706  16.0000  Unknown
#
#                 Embarked
# PassengerId
# 2              Cherbourg
# 4            Southampton
# 9            Southampton
# 10             Cherbourg
# 16           Southampton

# %%
mrs_df.insert(5, 'Minor', mrs_df['Age'] < 18)
mrs_df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 9                   1       3
# 10                  1       2
# 16                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
#
#              Minor  Family Size  SibSp  Parch    Ticket     Fare    Cabin  \
# PassengerId
# 2            False            1      1      0  PC 17599  71.2833      C85
# 4            False            1      1      0    113803  53.1000     C123
# 9            False            2      0      2    347742  11.1333  Unknown
# 10            True            1      1      0    237736  30.0708  Unknown
# 16           False            0      0      0    248706  16.0000  Unknown
#
#                 Embarked
# PassengerId
# 2              Cherbourg
# 4            Southampton
# 9            Southampton
# 10             Cherbourg
# 16           Southampton

# %%
mrs_df.drop(columns='Minor', inplace=True)
mrs_df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 9                   1       3
# 10                  1       2
# 16                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
#
#              Family Size  SibSp  Parch    Ticket     Fare    Cabin  \
# PassengerId
# 2                      1      1      0  PC 17599  71.2833      C85
# 4                      1      1      0    113803  53.1000     C123
# 9                      2      0      2    347742  11.1333  Unknown
# 10                     1      1      0    237736  30.0708  Unknown
# 16                     0      0      0    248706  16.0000  Unknown
#
#                 Embarked
# PassengerId
# 2              Cherbourg
# 4            Southampton
# 9            Southampton
# 10             Cherbourg
# 16           Southampton

# %%
mrs_df.drop(columns=['Survived', 'Pclass', 'Family Size', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], inplace=True)
mrs_df.head()
# Out:
#                                                           Name     Sex   Age
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0

# %% [markdown]
# ### 🔪 Splitting & Extracting Values

# %% [markdown]
# ```df['NEW_COLUMN'] = df['COLUMN'].str.extract(r'PATTERN')``` – Extracts substrings matching a regex pattern into a new column.
# ```df[['NEW_COLUMN_1', 'NEW_COLUMN_2']] = df['COLUMN'].str.split('DELIMITER', n=1, expand=True)``` – Splits a column by a delimiter into multiple new columns.

# %%
maiden_df = df.copy()
maiden_df['Maiden Name'] = maiden_df['Name'].str.extract(r'\(([^)]+)\)')
maiden_df[['Name', 'Maiden Name']].head()
# Out:
#                                                           Name  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                       Heikkinen, Miss. Laina
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                                     Allen, Mr. William Henry
#
#                         Maiden Name
# PassengerId
# 1                               NaN
# 2            Florence Briggs Thayer
# 3                               NaN
# 4                     Lily May Peel
# 5                               NaN

# %%
mrs_df[['Surname', 'Rest']] = mrs_df['Name'].str.split(',', expand=True)
mrs_df[['Title', 'Rest']] = mrs_df['Rest'].str.split('.', n=1, expand=True)
mrs_df[['Husband', 'Rest']] = mrs_df['Rest'].str.split('(', n=1, expand=True)
mrs_df.head()
# Out:
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
#
#               Surname                        Rest Title          Husband
# PassengerId
# 2             Cumings     Florence Briggs Thayer)   Mrs    John Bradley
# 4            Futrelle              Lily May Peel)   Mrs   Jacques Heath
# 9             Johnson  Elisabeth Vilhelmina Berg)   Mrs         Oscar W
# 10             Nasser                Adele Achem)   Mrs        Nicholas
# 16            Hewlett           Mary D Kingcome)    Mrs

# %%
mrs_df['Rest'] = mrs_df['Rest'].str.replace(')', '')
mrs_df['Husband'] = mrs_df['Husband'].replace(r'^\s*$', 'Unknown', regex=True)
mrs_df.head()
# Out:
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
#
#               Surname                       Rest Title          Husband
# PassengerId
# 2             Cumings     Florence Briggs Thayer   Mrs    John Bradley
# 4            Futrelle              Lily May Peel   Mrs   Jacques Heath
# 9             Johnson  Elisabeth Vilhelmina Berg   Mrs         Oscar W
# 10             Nasser                Adele Achem   Mrs        Nicholas
# 16            Hewlett           Mary D Kingcome    Mrs          Unknown

# %% [markdown]
# ### 🔗 Merging Columns

# %% [markdown]
# ```df['NEW_COLUMN'] = df['COLUMN_1'] + 'SEPARATOR' + df['COLUMN_2']``` – Creates a new column by concatenating two columns with a separator.

# %%
mrs_df['Husband Fullname'] = mrs_df['Surname'] + ',' + mrs_df['Husband']
mrs_df.head()
# Out:
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
#
#               Surname                       Rest Title          Husband  \
# PassengerId
# 2             Cumings     Florence Briggs Thayer   Mrs    John Bradley
# 4            Futrelle              Lily May Peel   Mrs   Jacques Heath
# 9             Johnson  Elisabeth Vilhelmina Berg   Mrs         Oscar W
# 10             Nasser                Adele Achem   Mrs        Nicholas
# 16            Hewlett           Mary D Kingcome    Mrs          Unknown
#
#                      Husband Fullname
# PassengerId
# 2              Cumings, John Bradley
# 4            Futrelle, Jacques Heath
# 9                   Johnson, Oscar W
# 10                  Nasser, Nicholas
# 16                    Hewlett,Unknown

# %% [markdown]
# ### ✏️ Renaming and Formatting

# %% [markdown]
# ```df.rename(columns={'OLD_NAME': 'NEW_NAME'}, inplace=True)``` – Renames a column.
# ```df.columns = ['COLUMN_1', 'COLUMN_2', 'COLUMN_3', ...]``` – Sets new column names explicitly.

# %%
mrs_df.rename(columns={'Rest': 'Maiden Name'}, inplace=True)
mrs_df.head()
# Out:
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
#
#               Surname                Maiden Name Title          Husband  \
# PassengerId
# 2             Cumings     Florence Briggs Thayer   Mrs    John Bradley
# 4            Futrelle              Lily May Peel   Mrs   Jacques Heath
# 9             Johnson  Elisabeth Vilhelmina Berg   Mrs         Oscar W
# 10             Nasser                Adele Achem   Mrs        Nicholas
# 16            Hewlett           Mary D Kingcome    Mrs          Unknown
#
#                      Husband Fullname
# PassengerId
# 2              Cumings, John Bradley
# 4            Futrelle, Jacques Heath
# 9                   Johnson, Oscar W
# 10                  Nasser, Nicholas
# 16                    Hewlett,Unknown

# %%
mrs_df.columns = ['Name', 'Gender', 'Age', 'Surname', 'Maiden Name', 'Title', 'Husband', 'Husband Fullname']
mrs_df.head()
# Out:
#                                                           Name  Gender   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
#
#               Surname                Maiden Name Title          Husband  \
# PassengerId
# 2             Cumings     Florence Briggs Thayer   Mrs    John Bradley
# 4            Futrelle              Lily May Peel   Mrs   Jacques Heath
# 9             Johnson  Elisabeth Vilhelmina Berg   Mrs         Oscar W
# 10             Nasser                Adele Achem   Mrs        Nicholas
# 16            Hewlett           Mary D Kingcome    Mrs          Unknown
#
#                      Husband Fullname
# PassengerId
# 2              Cumings, John Bradley
# 4            Futrelle, Jacques Heath
# 9                   Johnson, Oscar W
# 10                  Nasser, Nicholas
# 16                    Hewlett,Unknown

# %% [markdown]
# ### 🧵 Modifying Column Strings

# %% [markdown]
# ```df.columns = [x.lower() for x in df.columns]``` – Converts all column names to lowercase.
# ```df.columns = df.columns.str.replace(" ", "_")``` – Replaces spaces with underscores in column names.
# ```df['COLUMN'] = df['COLUMN'].str.upper()``` – Converts all values in a column to uppercase.

# %%
mrs_df.columns = [x.lower() for x in mrs_df.columns]
mrs_df.head()
# Out:
#                                                           name  gender   age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
#
#               surname                maiden name title          husband  \
# PassengerId
# 2             Cumings     Florence Briggs Thayer   Mrs    John Bradley
# 4            Futrelle              Lily May Peel   Mrs   Jacques Heath
# 9             Johnson  Elisabeth Vilhelmina Berg   Mrs         Oscar W
# 10             Nasser                Adele Achem   Mrs        Nicholas
# 16            Hewlett           Mary D Kingcome    Mrs          Unknown
#
#                      husband fullname
# PassengerId
# 2              Cumings, John Bradley
# 4            Futrelle, Jacques Heath
# 9                   Johnson, Oscar W
# 10                  Nasser, Nicholas
# 16                    Hewlett,Unknown

# %%
mrs_df.columns = mrs_df.columns.str.replace(" ", "_")
mrs_df.head()
# Out:
#                                                           name  gender   age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
#
#               surname                maiden_name title          husband  \
# PassengerId
# 2             Cumings     Florence Briggs Thayer   Mrs    John Bradley
# 4            Futrelle              Lily May Peel   Mrs   Jacques Heath
# 9             Johnson  Elisabeth Vilhelmina Berg   Mrs         Oscar W
# 10             Nasser                Adele Achem   Mrs        Nicholas
# 16            Hewlett           Mary D Kingcome    Mrs          Unknown
#
#                      husband_fullname
# PassengerId
# 2              Cumings, John Bradley
# 4            Futrelle, Jacques Heath
# 9                   Johnson, Oscar W
# 10                  Nasser, Nicholas
# 16                    Hewlett,Unknown

# %%
mrs_df['gender'] = mrs_df['gender'].str.upper()
mrs_df.head()
# Out:
#                                                           name  gender   age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  FEMALE  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  FEMALE  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  FEMALE  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  FEMALE  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   FEMALE  55.0
#
#               surname                maiden_name title          husband  \
# PassengerId
# 2             Cumings     Florence Briggs Thayer   Mrs    John Bradley
# 4            Futrelle              Lily May Peel   Mrs   Jacques Heath
# 9             Johnson  Elisabeth Vilhelmina Berg   Mrs         Oscar W
# 10             Nasser                Adele Achem   Mrs        Nicholas
# 16            Hewlett           Mary D Kingcome    Mrs          Unknown
#
#                      husband_fullname
# PassengerId
# 2              Cumings, John Bradley
# 4            Futrelle, Jacques Heath
# 9                   Johnson, Oscar W
# 10                  Nasser, Nicholas
# 16                    Hewlett,Unknown

# %% [markdown]
# ### 🧠 Applying Custom Functions

# %% [markdown]
# ```df['COLUMN'] = df['COLUMN'].apply(str.lower)``` – Applies the lowercase function to all entries in a column.
# ```df['COLUMN'] = df['COLUMN'].apply(custom_function)``` – Applies a custom function to a column.
# ```df['COLUMN'] = df['COLUMN'].apply(lambda x: x.lower())``` – Applies a lambda function to convert strings to lowercase.
# ```df['COLUMN'] = df['COLUMN'].replace({'OLD_VALUE': 'NEW_VALUE'})``` – Replaces specific values in a column according to a mapping.
# ```df['COLUMN'] = df['COLUMN'].map({'OLD_VALUE': 'NEW_VALUE'})``` – Maps old values to new values in a column.

# %%
mrs_df['gender'] = mrs_df['gender'].apply(str.lower)
mrs_df.head()
# Out:
#                                                           name  gender   age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
#
#               surname                maiden_name title          husband  \
# PassengerId
# 2             Cumings     Florence Briggs Thayer   Mrs    John Bradley
# 4            Futrelle              Lily May Peel   Mrs   Jacques Heath
# 9             Johnson  Elisabeth Vilhelmina Berg   Mrs         Oscar W
# 10             Nasser                Adele Achem   Mrs        Nicholas
# 16            Hewlett           Mary D Kingcome    Mrs          Unknown
#
#                      husband_fullname
# PassengerId
# 2              Cumings, John Bradley
# 4            Futrelle, Jacques Heath
# 9                   Johnson, Oscar W
# 10                  Nasser, Nicholas
# 16                    Hewlett,Unknown

# %%
def function_name(variable):
    return variable.title()

mrs_df['gender'] = mrs_df['gender'].apply(function_name)
mrs_df.head()
# Out:
#                                                           name  gender   age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  Female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  Female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  Female  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   Female  55.0
#
#               surname                maiden_name title          husband  \
# PassengerId
# 2             Cumings     Florence Briggs Thayer   Mrs    John Bradley
# 4            Futrelle              Lily May Peel   Mrs   Jacques Heath
# 9             Johnson  Elisabeth Vilhelmina Berg   Mrs         Oscar W
# 10             Nasser                Adele Achem   Mrs        Nicholas
# 16            Hewlett           Mary D Kingcome    Mrs          Unknown
#
#                      husband_fullname
# PassengerId
# 2              Cumings, John Bradley
# 4            Futrelle, Jacques Heath
# 9                   Johnson, Oscar W
# 10                  Nasser, Nicholas
# 16                    Hewlett,Unknown

# %%
mrs_df['gender'] = mrs_df['gender'].apply(lambda x: x.lower())
mrs_df.head()
# Out:
#                                                           name  gender   age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
#
#               surname                maiden_name title          husband  \
# PassengerId
# 2             Cumings     Florence Briggs Thayer   Mrs    John Bradley
# 4            Futrelle              Lily May Peel   Mrs   Jacques Heath
# 9             Johnson  Elisabeth Vilhelmina Berg   Mrs         Oscar W
# 10             Nasser                Adele Achem   Mrs        Nicholas
# 16            Hewlett           Mary D Kingcome    Mrs          Unknown
#
#                      husband_fullname
# PassengerId
# 2              Cumings, John Bradley
# 4            Futrelle, Jacques Heath
# 9                   Johnson, Oscar W
# 10                  Nasser, Nicholas
# 16                    Hewlett,Unknown

# %%
mrs_df['surname'] = mrs_df['surname'].replace({'Cumings': 'C.', 'Futrelle': 'F.'})
mrs_df.head()
# Out:
#                                                           name  gender   age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
#
#              surname                maiden_name title          husband  \
# PassengerId
# 2                 C.     Florence Briggs Thayer   Mrs    John Bradley
# 4                 F.              Lily May Peel   Mrs   Jacques Heath
# 9            Johnson  Elisabeth Vilhelmina Berg   Mrs         Oscar W
# 10            Nasser                Adele Achem   Mrs        Nicholas
# 16           Hewlett           Mary D Kingcome    Mrs          Unknown
#
#                      husband_fullname
# PassengerId
# 2              Cumings, John Bradley
# 4            Futrelle, Jacques Heath
# 9                   Johnson, Oscar W
# 10                  Nasser, Nicholas
# 16                    Hewlett,Unknown

# %%
mrs_df['gender'] = mrs_df['gender'].map({'female': 'F'})
mrs_df.head()
# Out:
#                                                           name gender   age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      F  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      F  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      F  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)      F  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)       F  55.0
#
#              surname                maiden_name title          husband  \
# PassengerId
# 2                 C.     Florence Briggs Thayer   Mrs    John Bradley
# 4                 F.              Lily May Peel   Mrs   Jacques Heath
# 9            Johnson  Elisabeth Vilhelmina Berg   Mrs         Oscar W
# 10            Nasser                Adele Achem   Mrs        Nicholas
# 16           Hewlett           Mary D Kingcome    Mrs          Unknown
#
#                      husband_fullname
# PassengerId
# 2              Cumings, John Bradley
# 4            Futrelle, Jacques Heath
# 9                   Johnson, Oscar W
# 10                  Nasser, Nicholas
# 16                    Hewlett,Unknown

# %% [markdown]
# ### 🎯 Conditional Modifications

# %% [markdown]
# ```filter = df['COLUMN'] == 'VALUE'``` – Creates a boolean mask for rows where a column equals a value.
# ```df.loc[filter, 'COLUMN_TO_MODIFY'] = 'NEW_VALUE'``` – Updates values in a column based on the condition.
# ```df['COLUMN'] = df['COLUMN'].where(df['COLUMN'] < VALUE, other=np.nan)``` – Sets values to `NaN` where a condition is not met.
# ```df['COLUMN'] = df['COLUMN'].clip(lower=LOWER_BOUND, upper=UPPER_BOUND)``` – Restricts values in a column to a specified range.

# %%
a_filter = mrs_df['surname'] == 'C.'
mrs_df.loc[a_filter, 'title'] = 'Lady'
mrs_df.head()
# Out:
#                                                           name gender   age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      F  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      F  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      F  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)      F  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)       F  55.0
#
#              surname                maiden_name title          husband  \
# PassengerId
# 2                 C.     Florence Briggs Thayer  Lady    John Bradley
# 4                 F.              Lily May Peel   Mrs   Jacques Heath
# 9            Johnson  Elisabeth Vilhelmina Berg   Mrs         Oscar W
# 10            Nasser                Adele Achem   Mrs        Nicholas
# 16           Hewlett           Mary D Kingcome    Mrs          Unknown
#
#                      husband_fullname
# PassengerId
# 2              Cumings, John Bradley
# 4            Futrelle, Jacques Heath
# 9                   Johnson, Oscar W
# 10                  Nasser, Nicholas
# 16                    Hewlett,Unknown

# %%
mrs_df['age'] = mrs_df['age'].where(mrs_df['age'] < 37, other=np.nan)
mrs_df.head()
# Out:
#                                                           name gender   age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      F   NaN
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      F  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      F  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)      F  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)       F   NaN
#
#              surname                maiden_name title          husband  \
# PassengerId
# 2                 C.     Florence Briggs Thayer  Lady    John Bradley
# 4                 F.              Lily May Peel   Mrs   Jacques Heath
# 9            Johnson  Elisabeth Vilhelmina Berg   Mrs         Oscar W
# 10            Nasser                Adele Achem   Mrs        Nicholas
# 16           Hewlett           Mary D Kingcome    Mrs          Unknown
#
#                      husband_fullname
# PassengerId
# 2              Cumings, John Bradley
# 4            Futrelle, Jacques Heath
# 9                   Johnson, Oscar W
# 10                  Nasser, Nicholas
# 16                    Hewlett,Unknown

# %%
mrs_df['age'] = mrs_df['age'].clip(lower=25, upper=35)
mrs_df.head()
# Out:
#                                                           name gender   age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      F   NaN
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      F  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      F  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)      F  25.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)       F   NaN
#
#              surname                maiden_name title          husband  \
# PassengerId
# 2                 C.     Florence Briggs Thayer  Lady    John Bradley
# 4                 F.              Lily May Peel   Mrs   Jacques Heath
# 9            Johnson  Elisabeth Vilhelmina Berg   Mrs         Oscar W
# 10            Nasser                Adele Achem   Mrs        Nicholas
# 16           Hewlett           Mary D Kingcome    Mrs          Unknown
#
#                      husband_fullname
# PassengerId
# 2              Cumings, John Bradley
# 4            Futrelle, Jacques Heath
# 9                   Johnson, Oscar W
# 10                  Nasser, Nicholas
# 16                    Hewlett,Unknown

# %% [markdown]
# ### ✍️ Modifying by Index or Label

# %% [markdown]
# ```df.loc[INDEX] = ['VALUE_1', 'VALUE_2', ...]``` – Replaces all column values in a row at a specific index.
# ```df.loc[INDEX, 'COLUMN'] = VALUE``` – Updates a single cell value by index and column label.
# ```df.loc[INDEX, ['COLUMN_1', 'COLUMN_2']] = [VALUE_1, VALUE_2]``` – Updates multiple columns in a row by index.
# ```df.at[INDEX, 'COLUMN'] = VALUE``` – Assigns a single value to a specific cell identified by label-based index and column.

# %%
mrs_df.loc[1] = ['Elisabth', 'female', 27, 'Queens', 'Mary Stone', 'Mrs', 'Jake', 'Jake Queen',]
mrs_df.tail()
# Out:
#                                                       name  gender   age  \
# PassengerId
# 875                  Abelson, Mrs. Samuel (Hannah Wizosky)       F  28.0
# 880          Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)       F   NaN
# 881           Shelley, Mrs. William (Imanita Parrish Hall)       F  25.0
# 886                   Rice, Mrs. William (Margaret Norton)       F   NaN
# 1                                                 Elisabth  female  27.0
#
#              surname           maiden_name title      husband  \
# PassengerId
# 875          Abelson        Hannah Wizosky   Mrs      Samuel
# 880           Potter  Lily Alexenia Wilson   Mrs   Thomas Jr
# 881          Shelley  Imanita Parrish Hall   Mrs     William
# 886             Rice       Margaret Norton   Mrs     William
# 1             Queens            Mary Stone   Mrs         Jake
#
#                husband_fullname
# PassengerId
# 875            Abelson, Samuel
# 880          Potter, Thomas Jr
# 881           Shelley, William
# 886              Rice, William
# 1                    Jake Queen

# %%
mrs_df.loc[2, 'age'] = 24
mrs_df.head()
# Out:
#                                                           name gender   age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      F  24.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      F  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      F  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)      F  25.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)       F   NaN
#
#              surname                maiden_name title          husband  \
# PassengerId
# 2                 C.     Florence Briggs Thayer  Lady    John Bradley
# 4                 F.              Lily May Peel   Mrs   Jacques Heath
# 9            Johnson  Elisabeth Vilhelmina Berg   Mrs         Oscar W
# 10            Nasser                Adele Achem   Mrs        Nicholas
# 16           Hewlett           Mary D Kingcome    Mrs          Unknown
#
#                      husband_fullname
# PassengerId
# 2              Cumings, John Bradley
# 4            Futrelle, Jacques Heath
# 9                   Johnson, Oscar W
# 10                  Nasser, Nicholas
# 16                    Hewlett,Unknown

# %%
mrs_df.loc[4, ['age', 'title']] = [37, 'Lady']
mrs_df.head()
# Out:
#                                                           name gender   age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      F  24.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      F  37.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      F  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)      F  25.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)       F   NaN
#
#              surname                maiden_name title          husband  \
# PassengerId
# 2                 C.     Florence Briggs Thayer  Lady    John Bradley
# 4                 F.              Lily May Peel  Lady   Jacques Heath
# 9            Johnson  Elisabeth Vilhelmina Berg   Mrs         Oscar W
# 10            Nasser                Adele Achem   Mrs        Nicholas
# 16           Hewlett           Mary D Kingcome    Mrs          Unknown
#
#                      husband_fullname
# PassengerId
# 2              Cumings, John Bradley
# 4            Futrelle, Jacques Heath
# 9                   Johnson, Oscar W
# 10                  Nasser, Nicholas
# 16                    Hewlett,Unknown

# %%
mrs_df.at[9, 'husband'] = ['Oscar', 'W', 'ayne']
mrs_df.head()
# Out:
#                                                           name gender   age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      F  24.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      F  37.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      F  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)      F  25.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)       F   NaN
#
#              surname                maiden_name title           husband  \
# PassengerId
# 2                 C.     Florence Briggs Thayer  Lady     John Bradley
# 4                 F.              Lily May Peel  Lady    Jacques Heath
# 9            Johnson  Elisabeth Vilhelmina Berg   Mrs  [Oscar, W, ayne]
# 10            Nasser                Adele Achem   Mrs         Nicholas
# 16           Hewlett           Mary D Kingcome    Mrs           Unknown
#
#                      husband_fullname
# PassengerId
# 2              Cumings, John Bradley
# 4            Futrelle, Jacques Heath
# 9                   Johnson, Oscar W
# 10                  Nasser, Nicholas
# 16                    Hewlett,Unknown

# %% [markdown]
# ### 👉 Next Topic: [Data Combining](./07-data-combining.ipynb)
#
# Learn how to combin data with pandas by Concatenation, Merging & Joining.
